# %%
# !git clone https://github.com/microsoft/unilm.git
# !pip uninstall --yes torch torchvision
# !pip install "torch==1.1.0" "torchvision==0.3.0"
# !pip install --user tensorboardX six numpy tqdm path.py lmdb pyarrow py-lz4framed methodtools py-rouge pyrouge nltk
# !pip install --user --editable /content/unilm/src

# !git clone -q https://github.com/NVIDIA/apex.git
# !cd apex && git reset --hard 1603407bf49c7fc3da74fceb6a6c7b47fece2ef8
# !cd apex && python setup.py install --user --cuda_ext --cpp_ext
# Out:
# Cloning into 'unilm'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 149 (delta 10), reused 9 (delta 2), pack-reused 124
# Receiving objects: 100% (149/149), 234.35 KiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (66/66), done.
# Uninstalling torch-1.3.1:
#   Successfully uninstalled torch-1.3.1
# Uninstalling torchvision-0.4.2:
#   Successfully uninstalled torchvision-0.4.2
# ...
#      |████████████████████████████████| 676.9MB 27kB/s
# ...
#      |████████████████████████████████| 2.6MB 25.3MB/s
# ...
#      |████████████████████████████████| 194kB 3.4MB/s
# ...
#      |████████████████████████████████| 133kB 37.3MB/s
# ...
#      |████████████████████████████████| 61kB 7.1MB/s
# ...
#      |████████████████████████████████| 61kB 6.2MB/s
# ...

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1Zj_nZWO7YffaOInj3Q4SZyn09Mb3In-e
# !gdown https://drive.google.com/uc?id=1USoQ8lJgN8kAWnUnRrupMGrPMLlDVqlV
# !unzip -n ggw_data.zip -d gigaword
# !unzip -n unilmv1-large-cased.zip
# !mkdir -p content out
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1Zj_nZWO7YffaOInj3Q4SZyn09Mb3In-e
# To: /content/unilmv1-large-cased.zip
# 618MB [00:03, 191MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1USoQ8lJgN8kAWnUnRrupMGrPMLlDVqlV
# To: /content/ggw_data.zip
# 578MB [00:03, 175MB/s]
# Archive:  ggw_data.zip
#   inflating: gigaword/dev.src
#   inflating: gigaword/dev.tgt
#    creating: gigaword/org_data/
#   inflating: gigaword/org_data/dev.src.txt
#   inflating: gigaword/org_data/dev.tgt.txt
#   inflating: gigaword/org_data/test.src.txt
#   inflating: gigaword/org_data/test.tgt.txt
#   inflating: gigaword/org_data/train.src.txt
#   inflating: gigaword/org_data/train.tgt.txt
#   inflating: gigaword/test.src
#   inflating: gigaword/test.tgt
#   inflating: gigaword/train.src
#   inflating: gigaword/train.src.10k
#   inflating: gigaword/train.tgt
#   inflating: gigaword/train.tgt.10k
# Archive:  unilmv1-large-cased.zip
#   inflating: unilmv1-large-cased.bin

# %%
# !export DATA_DIR="gigaword" &&\
export OUTPUT_DIR="out" &&\
export MODEL_RECOVER_PATH="unilmv1-large-cased.bin"\
&& python3 unilm/src/biunilm/run_seq2seq.py --do_train --amp --num_workers 0 \
  --bert_model bert-large-cased --new_segment_ids --tokenized_input \
  --data_dir ${DATA_DIR} --src_file train.src.10k --tgt_file train.tgt.10k \
  --output_dir ${OUTPUT_DIR}/bert_save \
  --log_dir ${OUTPUT_DIR}/bert_log \
  --model_recover_path ${MODEL_RECOVER_PATH} \
  --max_seq_length 192 --max_position_embeddings 192 \
  --trunc_seg a --always_truncate_tail --max_len_b 64 \
  --mask_prob 0.7 --max_pred 64 \
  --train_batch_size 16 --gradient_accumulation_steps 1 \
  --learning_rate 0.00001 --warmup_proportion 0.1 --label_smoothing 0.1 \
  --num_train_epochs 3 \
  --gradient_accumulation_steps 2
# Out:
# 12/07/2019 22:19:19 - INFO - __main__ -   device: cuda n_gpu: 1, distributed training: False, 16-bits training: False
# 12/07/2019 22:19:19 - INFO - pytorch_pretrained_bert.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-large-cased-vocab.txt not found in cache, downloading to /tmp/tmp_77_67cu
# 100% 213450/213450 [00:00<00:00, 2393832.46B/s]
# 12/07/2019 22:19:20 - INFO - pytorch_pretrained_bert.file_utils -   copying /tmp/tmp_77_67cu to cache at /root/.pytorch_pretrained_bert/cee054f6aafe5e2cf816d2228704e326446785f940f5451a5b26033516a4ac3d.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# 12/07/2019 22:19:20 - INFO - pytorch_pretrained_bert.file_utils -   creating metadata file for /root/.pytorch_pretrained_bert/cee054f6aafe5e2cf816d2228704e326446785f940f5451a5b26033516a4ac3d.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# ...

# %%
# !nvidia-smi
